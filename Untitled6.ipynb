# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnovasma091-svg/gldsky/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = '''
<!DOCTYPE html>
<html lang="az">
<head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
    <title>Gladio Control Panel</title>
    <style>
        :root{
            --bg:#0f1724; --card:#0b1220; --muted:#98a0b3; --accent:#60a5fa; --success:#34d399;
            --glass: rgba(255,255,255,0.03);
        }
        *{box-sizing:border-box}
        body{
            margin:0; font-family:Inter, system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
            background:linear-gradient(180deg,var(--bg),#2a51b4 60%);
            color:#e6eef8; -webkit-font-smoothing:antialiased;
            min-height:100vh;
        }
        .container{max-width:1100px;margin:28px auto;padding:20px}
        header{
            display:flex;align-items:center;justify-content:space-between;gap:16px;margin-bottom:20px;
        }
        .brand{display:flex;align-items:center;gap:12px}
        .logo{
            width:48px;height:48px;border-radius:8px;background:linear-gradient(135deg,var(--accent),#7c3aed);
            display:flex;align-items:center;justify-content:center;font-weight:700;color:#022047;box-shadow:0 4px 20px rgba(2,32,71,0.4)
        }
        h1{font-size:18px;margin:0}
        p.lead{margin:0;color:var(--muted);font-size:13px}
        .controls{display:flex;gap:10px;align-items:center}
        .btn{
            background:var(--card);border:1px solid rgba(255,255,255,0.04);padding:8px 12px;border-radius:8px;color:inherit;
            cursor:pointer;font-weight:600;font-size:13px;
        }
        .btn.primary{background:linear-gradient(90deg,var(--accent),#7c3aed);color:#021233;border:none}
        main{display:grid;grid-template-columns:260px 1fr;gap:18px;align-items:start}
        nav.sidebar{
            background:var(--card);padding:14px;border-radius:12px;box-shadow:0 6px 20px rgba(2,8,23,0.5);
            height:fit-content;
        }
        nav .section{margin-bottom:14px}
        nav h3{margin:0 0 8px 0;font-size:13px;color:var(--muted)}
        .nav-item{display:flex;align-items:center;gap:10px;padding:8px;border-radius:8px;color:inherit;cursor:pointer;font-size:14px}
        .nav-item:hover{background:var(--glass)}
        .dot{width:10px;height:10px;border-radius:50%;background:var(--success);box-shadow:0 0 8px rgba(52,211,153,0.18)}
        .panel{
            background:linear-gradient(180deg, rgba(255,255,255,0.02), rgba(255,255,255,0.01));
            padding:18px;border-radius:12px;box-shadow:0 8px 30px rgba(2,12,27,0.5);
        }
        .grid{display:grid;grid-template-columns:repeat(3,1fr);gap:12px;margin-bottom:12px}
        .card{
            background:linear-gradient(180deg, rgba(255,255,255,0.02), transparent);
            padding:12px;border-radius:10px;border:1px solid rgba(255,255,255,0.03);
        }
        .card h4{margin:0 0 8px 0;font-size:13px}
        .muted{color:var(--muted);font-size:13px}
        label.switch{
            position:relative;display:inline-block;width:44px;height:24px
        }
        label.switch input{opacity:0;width:0;height:0}
        .slider{
            position:absolute;cursor:pointer;inset:0;background:rgba(255,255,255,0.06);border-radius:24px;transition:all .2s
        }
        .slider:before{
            content:"";position:absolute;left:4px;top:4px;width:16px;height:16px;background:white;border-radius:50%;transform:scale(.9);transition:all .2s
        }
        label.switch input:checked + .slider{background:linear-gradient(90deg,var(--accent),#7c3aed)}
        label.switch input:checked + .slider:before{transform:translateX(20px) scale(.98);background:white}
        .footer-row{display:flex;gap:12px;align-items:center;justify-content:space-between;margin-top:12px}
        .logs{height:220px;overflow:auto;background:rgba(255,255,255,0.02);padding:12px;border-radius:8px;font-family:monospace;font-size:13px;color:var(--muted)}
        .form-row{display:flex;gap:8px}
        input[type="text"], select{
            background:transparent;border:1px solid rgba(255,255,255,0.05);padding:8px;border-radius:8px;color:inherit;min-width:0
        }
        .status-pill{
            display:inline-flex;align-items:center;gap:8px;padding:6px 10px;border-radius:999px;background:rgba(255,255,255,0.03)
        }
        .tag{font-size:12px;padding:4px 8px;border-radius:999px;background:rgba(255,255,255,0.03);color:var(--muted)}
        .toast{
            position:fixed;right:20px;bottom:20px;padding:12px 16px;border-radius:10px;background:#052033;color:#cfeeff;box-shadow:0 8px 30px rgba(2,8,23,0.6);display:none;
        }
        @media(max-width:880px){
            main{grid-template-columns:1fr; padding-bottom:40px}
            .grid{grid-template-columns:repeat(2,1fr)}
        }
        @media(max-width:520px){
            .grid{grid-template-columns:1fr}
            header{flex-direction:column;align-items:flex-start;gap:10px}
            .controls{width:100%;justify-content:space-between}
        }
    </style>
</head>
<body>
<div class="container">
    <header>
        <div class="brand">
            <div class="logo">G</div>
            <div>
                <h1>Gladio Control Panel</h1>
                <p class="lead">Sistem idarəetməsi və canlı nəzarət</p>
            </div>
        </div>
        <div class="controls">
            <div class="status-pill"><span class="dot" id="connDot"></span><span id="connText">Çevrimiçi</span></div>
            <button class="btn" id="snapshotBtn" title="Sistem görüntüsü">Ekran</button>
            <button class="btn primary" id="actionBtn">Əməliyyat Başlat</button>
        </div>
    </header>

    <main>
        <nav class="sidebar">
            <div class="section">
                <h3>Modullar</h3>
                <div class="nav-item" data-module="overview"><span>📊</span><span>Ümumi Baxış</span></div>
                <div class="nav-item" data-module="services"><span>⚙️</span><span>Xidmətlər</span></div>
                <div class="nav-item" data-module="network"><span>🌐</span><span>Şəbəkə</span></div>
                <div class="nav-item" data-module="logs"><span>📝</span><span>Girişlər</span></div>
            </div>

            <div class="section">
                <h3>Qısa Ayarlar</h3>
                <div style="display:flex;flex-direction:column;gap:8px">
                    <label style="display:flex;justify-content:space-between;align-items:center">
                        <span class="muted">Avtomatik Yenilə</span>
                        <label class="switch">
                            <input type="checkbox" id="autoRefresh" checked>
                            <span class="slider"></span>
                        </label>
                    </label>
                    <label style="display:flex;justify-content:space-between;align-items:center">
                        <span class="muted">Giriş Detallar</span>
                        <label class="switch">
                            <input type="checkbox" id="detailedLogs">
                            <span class="slider"></span>
                        </label>
                    </label>
                </div>
            </div>

            <div class="section">
                <h3>Sürətli Əmrlər</h3>
                <div class="form-row">
                    <input type="text" id="quickCmd" placeholder="Əmr yazın..." />
                    <button class="btn" id="runCmd">İcra et</button>
                </div>
            </div>
        </nav>

        <section>
            <div class="panel">
                <div class="grid">
                    <div class="card">
                        <h4>CPU İstifadəsi</h4>
                        <div style="font-size:20px;font-weight:700">34%</div>
                        <div class="muted">Orta yük: 0.84</div>
                    </div>
                    <div class="card">
                        <h4>Yaddaş</h4>
                        <div style="font-size:20px;font-weight:700">6.2 GB / 16 GB</div>
                        <div class="muted">Boş: 9.8 GB</div>
                    </div>
                    <div class="card">
                        <h4>Şəbəkə</h4>
                        <div style="font-size:20px;font-weight:700">120 Mbps</div>
                        <div class="muted">TX/RX: 32MB/64MB</div>
                    </div>
                </div>

                <div style="display:flex;gap:12px;flex-wrap:wrap;margin-bottom:12px">
                    <div style="flex:1;min-width:240px">
                        <h4>Xidmətlər</h4>
                        <div style="display:flex;gap:8px;margin-top:8px">
                            <div style="flex:1" class="card">
                                <div style="display:flex;justify-content:space-between;align-items:center">
                                    <div>
                                        <div style="font-weight:700">nginx</div>
                                        <div class="muted">Vəziyyəti: işləyir</div>
                                    </div>
                                    <label class="switch">
                                        <input type="checkbox" class="svc-toggle" data-svc="nginx" checked>
                                        <span class="slider"></span>
                                    </label>
                                </div>
                            </div>

                            <div style="flex:1" class="card">
                                <div style="display:flex;justify-content:space-between;align-items:center">
                                    <div>
                                        <div style="font-weight:700">db</div>
                                        <div class="muted">Vəziyyəti: dayandırılıb</div>
                                    </div>
                                    <label class="switch">
                                        <input type="checkbox" class="svc-toggle" data-svc="db">
                                        <span class="slider"></span>
                                    </label>
                                </div>
                            </div>
                        </div>
                    </div>

                    <div style="flex:1;min-width:260px">
                        <h4>Parametrlər</h4>
                        <div style="display:flex;flex-direction:column;gap:8px;margin-top:8px">
                            <label class="muted">Aydınlıq</label>
                            <input type="range" id="brightness" min="10" max="100" value="72" />
                            <div style="display:flex;justify-content:space-between;align-items:center">
                                <label class="muted">Profil</label>
                                <select id="profileSelect">
                                    <option>Standart</option>
                                    <option>Performans</option>
                                    <option>Aşağı Enerji</option>
                                </select>
                            </div>
                        </div>
                    </div>

                    <div style="flex:1;min-width:220px">
                        <h4>Fövqəladə</h4>
                        <div style="display:flex;flex-direction:column;gap:8px;margin-top:8px">
                            <button class="btn primary" id="restartBtn">Yenidən Başlat</button>
                            <button class="btn" id="shutdownBtn">Söndür</button>
                            <div class="muted" style="font-size:12px;margin-top:6px">Fövqəladə əməliyyatlar üçün təsdiq tələb olunur.</div>
                        </div>
                    </div>
                </div>

                <div>
                    <h4>Girişlər</h4>
                    <div class="logs" id="logs">
                        [10:34:21] Sistem yükləndi.
                        <br>[10:34:56] nginx başladıldı.
                        <br>[10:36:03] Uzaq bağlantı: 192.168.1.4
                    </div>

                    <div class="footer-row">
                        <div class="muted">Son yeniləmə: <span id="lastUpdate">indi</span></div>
                        <div style="display:flex;gap:8px">
                            <button class="btn" id="clearLogs">Təmizlə</button>
                            <button class="btn" id="exportLogs">Yüklə</button>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </main>
</div>

<div class="toast" id="toast">Əməliyyat tamamlandı</div>

<script>
    // Minimal interactivity
    const toast = id => {
        const el = document.getElementById('toast');
        el.textContent = id || 'Uğurla tamamlandı';
        el.style.display = 'block';
        setTimeout(()=> el.style.display='none', 2500);
    };

    document.getElementById('runCmd').addEventListener('click', () => {
        const cmd = document.getElementById('quickCmd').value.trim();
        if(!cmd){ toast('Əmr boşdur'); return; }
        const logs = document.getElementById('logs');
        const t = new Date().toLocaleTimeString();
        logs.innerHTML = `[${t}] İcra: ${escapeHtml(cmd)}<br>` + logs.innerHTML;
        document.getElementById('quickCmd').value = '';
        toast('Əmr göndərildi');
    });

    document.getElementById('actionBtn').addEventListener('click', ()=> {
        toast('Əməliyyat başlanıldı');
        // placeholder for real action
    });

    document.getElementById('snapshotBtn').addEventListener('click', ()=> {
        toast('Ekran görüntüsü yaradıldı');
    });

    document.getElementById('clearLogs').addEventListener('click', ()=> {
        document.getElementById('logs').innerHTML = '';
        toast('Girişlər təmizləndi');
    });

    document.getElementById('exportLogs').addEventListener('click', ()=> {
        const logs = document.getElementById('logs').innerText;
        const blob = new Blob([logs], {type:'text/plain'});
        const a = document.createElement('a');
        a.href = URL.createObjectURL(blob);
        a.download = 'gladio-logs.txt';
        a.click();
        URL.revokeObjectURL(a.href);
        toast('Girişlər yükləndi');
    });

    document.querySelectorAll('.svc-toggle').forEach(el=>{
        el.addEventListener('change', e=>{
            const svc = e.target.dataset.svc;
            const on = e.target.checked;
            const logs = document.getElementById('logs');
            const t = new Date().toLocaleTimeString();
            logs.innerHTML = `[${t}] ${svc} ${on ? 'işə salındı' : 'dayandırıldı'}<br>` + logs.innerHTML;
            toast(`${svc}: ${on ? 'işə salındı' : 'dayandırıldı'}`);
        });
    });

    document.getElementById('restartBtn').addEventListener('click', () => {
        if(!confirm('Sistemi yenidən başlatmaq istədiyinizə əminsiniz?')) return;
        const t = new Date().toLocaleTimeString();
        const logs = document.getElementById('logs');
        logs.innerHTML = `[${t}] Sistem yenidən başlatılır...<br>` + logs.innerHTML;
        toast('Yenidən başlatma sırası');
    });

    document.getElementById('shutdownBtn').addEventListener('click', () => {
        if(!confirm('Sistemi söndürmək istədiyinizə əminsiniz?')) return;
        const t = new Date().toLocaleTimeString();
        const logs = document.getElementById('logs');
        logs.innerHTML = `[${t}] Sistem söndürülür...<br>` + logs.innerHTML;
        toast('Söndürmə sırası');
    });

    // basic helper: escape HTML to avoid injection in log content
    function escapeHtml(str){
        return str.replace(/[&<\">']/g, function(m){ return ({'&':'&amp;','<':'&lt;','>':'&gt;','"':'&quot;','\'':'&#39;'}[m]); });
    }

    // quick navigation highlight
    document.querySelectorAll('nav .nav-item').forEach(item=>{
        item.addEventListener('click', ()=> {
            document.querySelectorAll('nav .nav-item').forEach(i=>i.style.opacity=1);
            item.style.opacity = 0.8;
            toast(item.dataset.module + ' seçildi');
        });
    });

    // simulate live update timestamp
    const updateTime = ()=> document.getElementById('lastUpdate').textContent = new Date().toLocaleTimeString();
    updateTime();
    setInterval(()=> {
        const auto = document.getElementById('autoRefresh').checked;
        if(auto){
            // Simulate metrics change
            updateTime();
        }
    }, 5000);
</script>
</body>
</html>
'''

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="az">
# <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#     <title>Gladio Control Panel</title>
#     <style>
#         :root{
#             --bg:#0f1724; --card:#0b1220; --muted:#98a0b3; --accent:#60a5fa; --success:#34d399;
#             --glass: rgba(255,255,255,0.03);
#         }
#         *{box-sizing:border-box}
#         body{
#             margin:0; font-family:Inter, system-ui, -apple-system, "Segoe UI", Roboto, "Helvetica Neue", Arial;
#             background:linear-gradient(180deg,var(--bg),#2a51b4 60%);
#             color:#e6eef8; -webkit-font-smoothing:antialiased;
#             min-height:100vh;
#         }
#         .container{max-width:1100px;margin:28px auto;padding:20px}
#         header{
#             display:flex;align-items:center;justify-content:space-between;gap:16px;margin-bottom:20px;
#         }
#         .brand{display:flex;align-items:center;gap:12px}
# ...

# %%
import webbrowser
import os

# HTML məzmununu müvəqqəti fayla yaz
file_path = 'temp_gladio_control_panel.html'
with open(file_path, 'w', encoding='utf-8') as f:
    f.write(html_content)

# Veb brauzerdə faylı aç
webbrowser.open('file://' + os.path.realpath(file_path))

print(f"HTML faylı '{file_path}' yaradıldı və brauzerdə açılmağa çalışıldı.")
# Out:
# HTML faylı 'temp_gladio_control_panel.html' yaradıldı və brauzerdə açılmağa çalışıldı.
